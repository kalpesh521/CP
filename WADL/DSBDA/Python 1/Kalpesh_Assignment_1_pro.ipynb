# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("dataset_Facebook.csv")
data
# Out:
#      Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 0              139441   Photo         2          12             4          3
# 1              139441  Status         2          12             3         10
# 2              139441   Photo         3          12             3          3
# 3              139441   Photo         2          12             2         10
# 4              139441   Photo         2          12             2          3
# ..                ...     ...       ...         ...           ...        ...
# 495             85093   Photo         3           1             7          2
# 496             81370   Photo         2           1             5          8
# 497             81370   Photo         1           1             5          2
# 498             81370   Photo         3           1             4         11
# 499             81370   Photo         2           1             4          4
#
# ...

# %%
data.isnull().sum()
# Out:
# Page total likes                                                       0
# Type                                                                   0
# Category                                                               0
# Post Month                                                             0
# Post Weekday                                                           0
# Post Hour                                                              0
# Paid                                                                   1
# Lifetime Post Total Reach                                              0
# Lifetime Post Total Impressions                                        0
# Lifetime Engaged Users                                                 0
# Lifetime Post Consumers                                                0
# Lifetime Post Consumptions                                             0
# Lifetime Post Impressions by people who have liked your Page           0
# ...

# %%
data=data.dropna()

# %%
data.isnull().sum()
# Out:
# Page total likes                                                       0
# Type                                                                   0
# Category                                                               0
# Post Month                                                             0
# Post Weekday                                                           0
# Post Hour                                                              0
# Paid                                                                   0
# Lifetime Post Total Reach                                              0
# Lifetime Post Total Impressions                                        0
# Lifetime Engaged Users                                                 0
# Lifetime Post Consumers                                                0
# Lifetime Post Consumptions                                             0
# Lifetime Post Impressions by people who have liked your Page           0
# ...

# %%
data.head()
# Out:
#    Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 0            139441   Photo         2          12             4          3
# 1            139441  Status         2          12             3         10
# 2            139441   Photo         3          12             3          3
# 3            139441   Photo         2          12             2         10
# 4            139441   Photo         2          12             2          3
#
#    Paid  Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# 0   0.0                       2752                             5091
# 1   0.0                      10460                            19057
# 2   0.0                       2413                             4373
# 3   1.0                      50128                            87991
# 4   0.0                       7244                            13594
#
#    Lifetime Engaged Users  Lifetime Post Consumers  \
# ...

# %%
data.tail()
# Out:
#      Page total likes   Type  Category  Post Month  Post Weekday  Post Hour  \
# 494             85093  Photo         3           1             7         10
# 495             85093  Photo         3           1             7          2
# 496             81370  Photo         2           1             5          8
# 497             81370  Photo         1           1             5          2
# 498             81370  Photo         3           1             4         11
#
#      Paid  Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# 494   0.0                       5400                             9218
# 495   0.0                       4684                             7536
# 496   0.0                       3480                             6229
# 497   0.0                       3778                             7216
# 498   0.0                       4156                             7564
#
#      Lifetime Engaged Users  Lifetime Post Consumers  \
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 495 entries, 0 to 498
# Data columns (total 19 columns):
#  #   Column                                                               Non-Null Count  Dtype
# ---  ------                                                               --------------  -----
#  0   Page total likes                                                     495 non-null    int64
#  1   Type                                                                 495 non-null    object
#  2   Category                                                             495 non-null    int64
#  3   Post Month                                                           495 non-null    int64
#  4   Post Weekday                                                         495 non-null    int64
#  5   Post Hour                                                            495 non-null    int64
#  6   Paid                                                                 495 non-null    float64
# ...

# %%
data.columns
# Out:
# Index(['Page total likes', 'Type', 'Category', 'Post Month', 'Post Weekday',
#        'Post Hour', 'Paid', 'Lifetime Post Total Reach',
#        'Lifetime Post Total Impressions', 'Lifetime Engaged Users',
#        'Lifetime Post Consumers', 'Lifetime Post Consumptions',
#        'Lifetime Post Impressions by people who have liked your Page',
#        'Lifetime Post reach by people who like your Page',
#        'Lifetime People who have liked your Page and engaged with your post',
#        'comment', 'like', 'share', 'Total Interactions'],
#       dtype='object')

# %% [markdown]
# ## Creating Subsets

# %%
data_colm1= data[['Page total likes','Category','Post Month','Paid','share']]
data_colm1
# Out:
#      Page total likes  Category  Post Month  Paid  share
# 0              139441         2          12   0.0   17.0
# 1              139441         2          12   0.0   29.0
# 2              139441         3          12   0.0   14.0
# 3              139441         2          12   1.0  147.0
# 4              139441         2          12   0.0   49.0
# ..                ...       ...         ...   ...    ...
# 494             85093         3           1   0.0   41.0
# 495             85093         3           1   0.0   26.0
# 496             81370         2           1   0.0   22.0
# 497             81370         1           1   0.0   18.0
# 498             81370         3           1   0.0   38.0
#
# [495 rows x 5 columns]

# %%
#Creating row subset

data_row= data.iloc[[1,4,5,7,9]]
data_row
# Out:
#    Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 1            139441  Status         2          12             3         10
# 4            139441   Photo         2          12             2          3
# 5            139441  Status         2          12             1          9
# 7            139441   Photo         3          12             7          9
# 9            139441   Photo         3          12             6         10
#
#    Paid  Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# 1   0.0                      10460                            19057
# 4   0.0                       7244                            13594
# 5   0.0                      10472                            20849
# 7   1.0                      13720                            24137
# 9   0.0                       4694                             8668
#
#    Lifetime Engaged Users  Lifetime Post Consumers  \
# ...

# %%
data_row2=data.iloc[[2,8,10]]
data_row2
# Out:
#     Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 2             139441   Photo         3          12             3          3
# 8             139441  Status         2          12             7          3
# 10            139441  Status         2          12             5         10
#
#     Paid  Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# 2    0.0                       2413                             4373
# 8    0.0                      11844                            22538
# 10   0.0                      21744                            42334
#
#     Lifetime Engaged Users  Lifetime Post Consumers  \
# 2                      177                      113
# 8                     1530                     1407
# 10                    4258                     4100
#
#     Lifetime Post Consumptions  \
# 2                          154
# 8                         1692
# 10                        4540
#
# ...

# %%
conc= pd.concat([data_row,data_row2])
conc
# Out:
#     Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 1             139441  Status         2          12             3         10
# 4             139441   Photo         2          12             2          3
# 5             139441  Status         2          12             1          9
# 7             139441   Photo         3          12             7          9
# 9             139441   Photo         3          12             6         10
# 2             139441   Photo         3          12             3          3
# 8             139441  Status         2          12             7          3
# 10            139441  Status         2          12             5         10
#
#     Paid  Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# 1    0.0                      10460                            19057
# 4    0.0                       7244                            13594
# 5    0.0                      10472                            20849
# ...

# %%
merged = pd.merge(data_row,data_row2,on='Page total likes')
merged

#  merge() is used to combine DataFrames based on a common column or index, performing various types of joins.
# On the other hand, concat() is used to concatenate DataFrames either vertically or horizontally,
# stacking them on top of each other or side by side.
# Out:
#     Page total likes  Type_x  Category_x  Post Month_x  Post Weekday_x  \
# 0             139441  Status           2            12               3
# 1             139441  Status           2            12               3
# 2             139441  Status           2            12               3
# 3             139441   Photo           2            12               2
# 4             139441   Photo           2            12               2
# 5             139441   Photo           2            12               2
# 6             139441  Status           2            12               1
# 7             139441  Status           2            12               1
# 8             139441  Status           2            12               1
# 9             139441   Photo           3            12               7
# 10            139441   Photo           3            12               7
# 11            139441   Photo           3            12               7
# ...

# %%
#Sort data of subsets 
sort_data= conc.sort_values(by="Category")
sort_data
# Out:
#     Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 1             139441  Status         2          12             3         10
# 4             139441   Photo         2          12             2          3
# 5             139441  Status         2          12             1          9
# 8             139441  Status         2          12             7          3
# 10            139441  Status         2          12             5         10
# 7             139441   Photo         3          12             7          9
# 9             139441   Photo         3          12             6         10
# 2             139441   Photo         3          12             3          3
#
#     Paid  Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# 1    0.0                      10460                            19057
# 4    0.0                       7244                            13594
# 5    0.0                      10472                            20849
# ...

# %%
#Transpose dataframe : 
# you can use the transpose() function or the .T attribute to transpose a DataFrame, which essentially flips the rows and columns.
# This operation converts the columns into rows and vice versa

trans= sort_data.transpose()
trans
# Out:
#                                                         1       4       5   \
# Page total likes                                    139441  139441  139441
# Type                                                Status   Photo  Status
# Category                                                 2       2       2
# Post Month                                              12      12      12
# Post Weekday                                             3       2       1
# Post Hour                                               10       3       9
# Paid                                                   0.0     0.0     0.0
# Lifetime Post Total Reach                            10460    7244   10472
# Lifetime Post Total Impressions                      19057   13594   20849
# Lifetime Engaged Users                                1457     671    1191
# Lifetime Post Consumers                               1361     410    1073
# ...

# %%
# The resulting melted_df DataFrame is reshaped, 
# where each row represents a unique combination of student name, subject, and score.
# specifies the columns to be melted using the value_vars parameter. the columns to be melted are "Category" and "Post Month". 
# The id_vars parameter is set to "Type" to keep the "Type" column fixed and unchanged

reshape_data= pd.melt(sort_data,id_vars="Type",value_vars=["Category","Post Month"])
reshape_data
# Out:
#       Type    variable  value
# 0   Status    Category      2
# 1    Photo    Category      2
# 2   Status    Category      2
# 3   Status    Category      2
# 4   Status    Category      2
# 5    Photo    Category      3
# 6    Photo    Category      3
# 7    Photo    Category      3
# 8   Status  Post Month     12
# 9    Photo  Post Month     12
# 10  Status  Post Month     12
# 11  Status  Post Month     12
# 12  Status  Post Month     12
# 13   Photo  Post Month     12
# 14   Photo  Post Month     12
# 15   Photo  Post Month     12
