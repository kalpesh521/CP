# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv("airquality2.csv")
data
# Out:
#      Unnamed: 0  Ozone  Solar.R  Wind  Temp  Month  Day Humidity
# 0             1   41.0    190.0   7.4    67      5    1     High
# 1             2   36.0    118.0   8.0    72      5    2     High
# 2             3   12.0    149.0  12.6    74      5    3      NaN
# 3             4   18.0    313.0  11.5    62      5    4   Medium
# 4             5    NaN      NaN  14.3    56      5    5      Low
# ..          ...    ...      ...   ...   ...    ...  ...      ...
# 148         149   30.0    193.0   6.9    70      9   26      Low
# 149         150    NaN    145.0  13.2    77      9   27      Low
# 150         151   14.0    191.0  14.3    75      9   28     High
# 151         152   18.0    131.0   8.0    76      9   29     High
# 152         153   20.0    223.0  11.5    68      9   30   Medium
#
# [153 rows x 8 columns]

# %%
data['Ozone'].fillna(data['Ozone'].mean(),inplace = True)
data['Solar.R'].fillna(data['Solar.R'].mean(),inplace=True)
data.drop('Unnamed: 0',axis=1,inplace =True)

# %%
data['Humidity'].fillna('Medium',inplace=True)

# %%
data
# Out:
#         Ozone     Solar.R  Wind  Temp  Month  Day Humidity
# 0    41.00000  190.000000   7.4    67      5    1     High
# 1    36.00000  118.000000   8.0    72      5    2     High
# 2    12.00000  149.000000  12.6    74      5    3   Medium
# 3    18.00000  313.000000  11.5    62      5    4   Medium
# 4    42.12931  185.931507  14.3    56      5    5      Low
# ..        ...         ...   ...   ...    ...  ...      ...
# 148  30.00000  193.000000   6.9    70      9   26      Low
# 149  42.12931  145.000000  13.2    77      9   27      Low
# 150  14.00000  191.000000  14.3    75      9   28     High
# 151  18.00000  131.000000   8.0    76      9   29     High
# 152  20.00000  223.000000  11.5    68      9   30   Medium
#
# [153 rows x 7 columns]

# %% [markdown]
# ## Piechart

# %%
data1 = [data['Ozone'].mean(), data['Solar.R'].mean() ,data['Wind'].mean(), data['Temp'].mean()]
autopct="%1.2f%%"
explode=[0.01, 0.01, 0.01, 0.01]
labels=['Ozone','Solar.R','Wind','Temp']

#data1
plt.pie(x=data1,autopct=autopct,explode=explode,labels=labels)
plt.plot()
# Out:
# []

# %%
data.isnull().sum()
# Out:
# Ozone       0
# Solar.R     0
# Wind        0
# Temp        0
# Month       0
# Day         0
# Humidity    0
# dtype: int64

# %%
plt.pie([data["Ozone"].mean(),data["Solar.R"].mean(),data["Wind"].mean(),data["Temp"].mean()], autopct="%1.2f%%", explode=[0.01,0.01,0.01,0.01], labels=["Ozone", "Solar.R", "Wind", "Temp"])
plt.plot()

# %% [markdown]
# ## Barplot

# %%
sns.barplot(data=data,x="Month",y="Temp")
plt.title('Temperature ')
# the black vertical line in the middle of a boxplot represents the median value, 
# providing information about the central tendency of the dataset being visualized
# Out:
# Text(0.5, 1.0, 'Temperature ')

# %%
plt.bar(data['Month'],data['Temp'])
plt.show()

# %% [markdown]
# ## Box Plot

# %%
sns.boxenplot(data=data,x='Month',y='Temp')

'''
Box: The box in the plot represents the interquartile range (IQR), which spans from the 25th percentile (Q1) to the 75th percentile (Q3).
It provides insights into the central tendency and spread of the data.

Median: The line inside the box represents the median value, which is the middle value of the dataset when it is sorted.

Whiskers: The whiskers extend from the box and represent the range of the data. Typically,
they extend to the most extreme data points within a certain distance from the box, usually defined as 1.5 times the IQR.

Outliers: Data points that fall outside the whiskers are considered outliers and are plotted individually as points.
Outliers can indicate unusual or extreme values in the dataset.

Notch: An optional feature of the boxplot is the notch, which is a narrowing of the box around the median.
It provides a rough indication of the confidence interval around the median.
'''
# Out:
# <AxesSubplot:xlabel='Month', ylabel='Temp'>

# %% [markdown]
#  ## Histogram

# %%
plt.hist(x=data['Temp'],bins=20,color='orange',label='Temp')
# Out:
# (array([ 6.,  2.,  5.,  3.,  5.,  8.,  4.,  6.,  9., 13., 13., 11., 20.,
#          9., 12.,  8.,  5.,  7.,  5.,  2.]),
#  array([56.  , 58.05, 60.1 , 62.15, 64.2 , 66.25, 68.3 , 70.35, 72.4 ,
#         74.45, 76.5 , 78.55, 80.6 , 82.65, 84.7 , 86.75, 88.8 , 90.85,
#         92.9 , 94.95, 97.  ]),
#  <BarContainer object of 20 artists>)

# %%
plt.title('Histogram')
sns.histplot(data=data,x='Temp',bins=30,hue='Humidity')
# Out:
# <AxesSubplot:title={'center':'Histogram'}, xlabel='Temp', ylabel='Count'>

# %% [markdown]
# ## Heatmap

# %%
sns.heatmap(data.corr(),linecolor="white",linewidths=2,annot=True)

# The heatmap represents the pairwise correlations between the variables, 
# with higher correlation values indicated by different colors or intensity levels. 
# data.corr(): This computes the correlation matrix of the DataFrame data. 
# The correlation matrix measures the linear relationship between pairs of variables in the DataFrame.
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Line Graph

# %%
plt.plot(data.iloc[0:30,5],data.iloc[0:30,2],color="purple")
plt.xlabel("Day")
plt.ylabel("Wind")
plt.title("Wind vs Day")
# Out:
# Text(0.5, 1.0, 'Wind vs Day')

# %%
data.columns
# Out:
# Index(['Ozone', 'Solar.R', 'Wind', 'Temp', 'Month', 'Day', 'Humidity'], dtype='object')

# %% [markdown]
#  ## Scatterplot

# %%
plt.scatter(data.iloc[0:30,5],data.iloc[0:30,2],color="green")

# %% [markdown]
# ## Pairplot

# %%
sns.pairplot(data.iloc[:,[1,2,3,4,6]],hue="Humidity")
plt.show()

# selected columns from the DataFrame data, showing the pairwise relationships between these variables. 
# Each scatter plot in the grid represents the relationship between two variables, and
# the hue variable (Humidity) is used to color the data points in the scatter plots.
# sns.pairplot(): This function is from the seaborn library and is used to create a grid of scatter plots.
# hue="Humidity": This parameter is used to specify the variable in the DataFrame data that will be used to color the data points.

# %%
from wordcloud import WordCloud , STOPWORDS
# WordCloud is the class that allows us to generate word clouds, and
# STOPWORDS is a predefined set of common words that are often excluded from word clouds.
stopwords=set(STOPWORDS) 
# This line initializes a set of stopwords using the STOPWORDS variable

text='''India is my country Vision is the power that sustains. Whatever we keep in front of our eyes is what will determine our outcome 
 Successful people know that true education is what you get for yourself and by yourself, it’s not what someone gives or
 tells you  they know that true success in life does not come by luck, a lucky man is not a successful man, true winners
 know that they must develop skills and acquire knowledge before becoming truly successful.'''

wordcloud = WordCloud(width=1000,height=1000,background_color='white',
                     stopwords=stopwords,min_font_size=10).generate(text)
#  the generate(text) method generates the word cloud based on the provided input text
plt.imshow(wordcloud) # This line displays the word cloud image using the imshow() function from matplotlib.pyplo
plt.tight_layout(pad=0)# This line adjusts the padding of the plot to ensure all elements are properly displayed.
plt.axis("off") #: This line turns off the axis labels and ticks, so they are not displayed in the plot.
plt.show() #: This line displays the plot with the generated word cloud.
