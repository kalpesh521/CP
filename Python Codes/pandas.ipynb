# %%
import pandas as pd
import numpy as np

# %%
pd.__version__
# Out:
# '1.4.2'

# %%
#pandas consist of two data structures
#1. Series      1D  labelled data column
#2. Dataframe   2D data ,row and column

ser=pd.Series()
print(ser)
data = np.array(['K','A','L','P','E','S','H'])
ser=pd.Series(data)
ser
# Out:
# Series([], dtype: float64)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_22088\2574688788.py:5: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   ser=pd.Series()
# 0    K
# 1    A
# 2    L
# 3    P
# 4    E
# 5    S
# 6    H
# dtype: object

# %%
#Creating Dataframe
lst=['India','is','my','country']
df=pd.DataFrame(lst)
df
# Out:
#          0
# 0    India
# 1       is
# 2       my
# 3  country

# %%
data ={'Name':['kp','Sp','pp','kpm'],
     'Loc':['pune','Mumbai','Thane','Dubai'],
     'Salary':['1k','2K','3K','4K']}
df=pd.DataFrame(data)
print(df[['Name','Salary']])
# Out:
#   Name Salary
# 0   kp     1k
# 1   Sp     2K
# 2   pp     3K
# 3  kpm     4K

# %%
df1=pd.read_csv('airquality.csv')
df1
# Out:
#      Unnamed: 0  Ozone  Solar.R  Wind  Temp  Month  Day
# 0             1   41.0    190.0   7.4    67      5    1
# 1             2   36.0    118.0   8.0    72      5    2
# 2             3   12.0    149.0  12.6    74      5    3
# 3             4   18.0    313.0  11.5    62      5    4
# 4             5    NaN      NaN  14.3    56      5    5
# ..          ...    ...      ...   ...   ...    ...  ...
# 148         149   30.0    193.0   6.9    70      9   26
# 149         150    NaN    145.0  13.2    77      9   27
# 150         151   14.0    191.0  14.3    75      9   28
# 151         152   18.0    131.0   8.0    76      9   29
# 152         153   20.0    223.0  11.5    68      9   30
#
# [153 rows x 7 columns]

# %%
df1.columns
# Out:
# Index(['Unnamed: 0', 'Ozone', 'Solar.R', 'Wind', 'Temp', 'Month', 'Day'], dtype='object')

# %%
df1.isnull().count()
# Out:
# Unnamed: 0    153
# Ozone         153
# Solar.R       153
# Wind          153
# Temp          153
# Month         153
# Day           153
# dtype: int64

# %%
df1.fillna(0) #Replace null value with 0
df1.dropna()  #Drop null values rows
# Out:
#      Unnamed: 0  Ozone  Solar.R  Wind  Temp  Month  Day
# 0             1   41.0    190.0   7.4    67      5    1
# 1             2   36.0    118.0   8.0    72      5    2
# 2             3   12.0    149.0  12.6    74      5    3
# 3             4   18.0    313.0  11.5    62      5    4
# 6             7   23.0    299.0   8.6    65      5    7
# ..          ...    ...      ...   ...   ...    ...  ...
# 147         148   14.0     20.0  16.6    63      9   25
# 148         149   30.0    193.0   6.9    70      9   26
# 150         151   14.0    191.0  14.3    75      9   28
# 151         152   18.0    131.0   8.0    76      9   29
# 152         153   20.0    223.0  11.5    68      9   30
#
# [109 rows x 7 columns]

# %%
#iterating over rows
for i,j in df1.iterrows(): #iterrows -> Show each element of rows
    print(i,j)
    print()
# Out:
# 0 Unnamed: 0      1.0
# Ozone          41.0
# Solar.R       190.0
# Wind            7.4
# Temp           67.0
# Month           5.0
# Day             1.0
# Name: 0, dtype: float64
#
# 1 Unnamed: 0      2.0
# Ozone          36.0
# Solar.R       118.0
# Wind            8.0
# Temp           72.0
# Month           5.0
# Day             2.0
# Name: 1, dtype: float64
#
# 2 Unnamed: 0      3.0
# Ozone          12.0
# Solar.R       149.0
# Wind           12.6
# Temp           74.0
# Month           5.0
# Day             3.0
# Name: 2, dtype: float64
#
# 3 Unnamed: 0      4.0
# Ozone          18.0
# Solar.R       313.0
# Wind           11.5
# Temp           62.0
# Month           5.0
# Day             4.0
# Name: 3, dtype: float64
#
# 4 Unnamed: 0     5.0
# Ozone          NaN
# Solar.R        NaN
# Wind          14.3
# Temp          56.0
# Month          5.0
# Day            5.0
# Name: 4, dtype: float64
#
# 5 Unnamed: 0     6.0
# Ozone         28.0
# Solar.R        NaN
# Wind          14.9
# ...

# %%
df1.head()
# Out:
#    Unnamed: 0  Ozone  Solar.R  Wind  Temp  Month  Day
# 0           1   41.0    190.0   7.4    67      5    1
# 1           2   36.0    118.0   8.0    72      5    2
# 2           3   12.0    149.0  12.6    74      5    3
# 3           4   18.0    313.0  11.5    62      5    4
# 4           5    NaN      NaN  14.3    56      5    5

# %%
#iterating over columns

clmn=list(df1)
clmn
for i in clmn:
    print(df1[i][2])
# Out:
# 3
# 12.0
# 149.0
# 12.6
# 74
# 5
# 3

# %%
df1.drop(['Unnamed: 0'],axis=1,inplace=True) #Drop column

# %%
df1.dropna(inplace=True) #Null Values row deleted

# %%
df1.head(n=8)
# Out:
#     Ozone  Solar.R  Wind  Temp  Month  Day
# 0    41.0    190.0   7.4    67      5    1
# 1    36.0    118.0   8.0    72      5    2
# 2    12.0    149.0  12.6    74      5    3
# 3    18.0    313.0  11.5    62      5    4
# 6    23.0    299.0   8.6    65      5    7
# 7    19.0     99.0  13.8    59      5    8
# 8     8.0     19.0  20.1    61      5    9
# 11   16.0    256.0   9.7    69      5   12

# %%
df
# Out:
#   Name     Loc Salary
# 0   kp    pune     1k
# 1   Sp  Mumbai     2K
# 2   pp   Thane     3K
# 3  kpm   Dubai     4K

# %%
Number=[11,22,33,44]  #Addition Column
df['Number']=Number
df
# Out:
#   Name     Loc Salary  Number
# 0   kp    pune     1k      11
# 1   Sp  Mumbai     2K      22
# 2   pp   Thane     3K      33
# 3  kpm   Dubai     4K      44

# %%
df.drop([3],inplace=True) #deletion of row

# %%
df
# Out:
#   Name     Loc Salary  Number
# 0   kp    pune     1k      11
# 1   Sp  Mumbai     2K      22
# 2   pp   Thane     3K      33

# %%
df1.head(n=15)
# Out:
#     Ozone  Solar.R  Wind  Temp  Month  Day
# 0    41.0    190.0   7.4    67      5    1
# 1    36.0    118.0   8.0    72      5    2
# 2    12.0    149.0  12.6    74      5    3
# 3    18.0    313.0  11.5    62      5    4
# 6    23.0    299.0   8.6    65      5    7
# 7    19.0     99.0  13.8    59      5    8
# 8     8.0     19.0  20.1    61      5    9
# 11   16.0    256.0   9.7    69      5   12
# 12   11.0    290.0   9.2    66      5   13
# 13   14.0    274.0  10.9    68      5   14
# 14   18.0     65.0  13.2    58      5   15
# 15   14.0    334.0  11.5    64      5   16
# 16   34.0    307.0  12.0    66      5   17
# 17    6.0     78.0  18.4    57      5   18
# 19   11.0     44.0   9.7    62      5   20

# %%
df1.loc[12]  #retrive rows
df1.loc[3:12]  #retrive rows between two indices , used for labels 
df1.iloc[3:12]  #Different than loc retrive rows between two indices ,Used for numeric values
#df1.ix[3:12]  #Different than loc retrive rows between two indices
# Out:
#     Ozone  Solar.R  Wind  Temp  Month  Day
# 3    18.0    313.0  11.5    62      5    4
# 6    23.0    299.0   8.6    65      5    7
# 7    19.0     99.0  13.8    59      5    8
# 8     8.0     19.0  20.1    61      5    9
# 11   16.0    256.0   9.7    69      5   12
# 12   11.0    290.0   9.2    66      5   13
# 13   14.0    274.0  10.9    68      5   14
# 14   18.0     65.0  13.2    58      5   15
# 15   14.0    334.0  11.5    64      5   16

# %%
df
# Out:
#   Name     Loc Salary  Number
# 0   kp    pune     1k      11
# 1   Sp  Mumbai     2K      22
# 2   pp   Thane     3K      33

# %%
df2={"Name":"VR","Loc":"Gurugaon","Salary":"3K","Number":"44"}#Add one row by using append Method
df=df.append(df2,ignore_index=True)
print(df)
# Out:
#   Name       Loc Salary Number
# 0   kp      pune     1k     11
# 1   Sp    Mumbai     2K     22
# 2   pp     Thane     3K     33
# 3   VR  Gurugaon     3K     44
# C:\Users\Admin\AppData\Local\Temp\ipykernel_22088\3020687670.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df=df.append(df2,ignore_index=True)

# %%
df
# Out:
#   Name       Loc Salary Number
# 0   kp      pune     1k     11
# 1   Sp    Mumbai     2K     22
# 2   pp     Thane     3K     33
# 3   VR  Gurugaon     3K     44

# %%
data1={"Name":["kp","Sp","pp"],
    "Loc":["a","b","c"],
    "Salary":["1K","3k","3k"],
    "Number":[55,66,44]
    }

# %%
df3=pd.DataFrame(data1)
df3
# Out:
#   Name Loc Salary  Number
# 0   kp   a     1K      55
# 1   Sp   b     3k      66
# 2   pp   c     3k      44

# %%
con=pd.concat([df,df3],ignore_index=True)#Concatanation of two dictionaries
con
# Out:
#   Name       Loc Salary Number
# 0   kp      pune     1k     11
# 1   Sp    Mumbai     2K     22
# 2   pp     Thane     3K     33
# 3   VR  Gurugaon     3K     44
# 4   kp         a     1K     55
# 5   Sp         b     3k     66
# 6   pp         c     3k     44

# %%
con=pd.concat([df,df3],axis=1,join='inner')#Now we set axes join = inner for intersection of dataframe
con
# Out:
#   Name     Loc Salary  Number Name Loc Salary  Number
# 0   kp    pune     1k      11   kp   a     1K      55
# 1   Sp  Mumbai     2K      22   Sp   b     3k      66
# 2   pp   Thane     3K      33   pp   c     3k      44

# %%
con=pd.concat([df,df3],axis=1,sort=False)#we set axes join = outer for union of dataframe.
con
# Out:
#   Name       Loc Salary Number
# 0   kp      pune     1k     11
# 1   Sp    Mumbai     2K     22
# 2   pp     Thane     3K     33
# 3   VR  Gurugaon     3K     44
# 0   kp         a     1K     55
# 1   Sp         b     3k     66
# 2   pp         c     3k     44

# %%
#Group By
grp=con.groupby('Name').groups

grp=con.groupby('Name')
grp.get_group('Sp')
# Out:
#   Name     Loc Salary Number
# 1   Sp  Mumbai     2K     22
# 5   Sp       b     3k     66

# %%
#Group By
for Name ,group in grp:
    print(Name)
    print(group)
    print()
# Out:
# Sp
#   Name     Loc Salary Number
# 1   Sp  Mumbai     2K     22
# 5   Sp       b     3k     66
#
# VR
#   Name       Loc Salary Number
# 3   VR  Gurugaon     3K     44
#
# kp
#   Name   Loc Salary Number
# 0   kp  pune     1k     11
# 4   kp     a     1K     55
#
# pp
#   Name    Loc Salary Number
# 2   pp  Thane     3K     33
# 6   pp      c     3k     44
