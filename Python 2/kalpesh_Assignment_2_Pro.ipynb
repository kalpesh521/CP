# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
import warnings
warnings.filterwarnings('ignore')
import seaborn as sns

# %%
df= pd.read_csv("airquality2.csv")
df
# Out:
#      Unnamed: 0  Ozone  Solar.R  Wind  Temp  Month  Day Humidity
# 0             1   41.0    190.0   7.4    67      5    1     High
# 1             2   36.0    118.0   8.0    72      5    2     High
# 2             3   12.0    149.0  12.6    74      5    3      NaN
# 3             4   18.0    313.0  11.5    62      5    4   Medium
# 4             5    NaN      NaN  14.3    56      5    5      Low
# ..          ...    ...      ...   ...   ...    ...  ...      ...
# 148         149   30.0    193.0   6.9    70      9   26      Low
# 149         150    NaN    145.0  13.2    77      9   27      Low
# 150         151   14.0    191.0  14.3    75      9   28     High
# 151         152   18.0    131.0   8.0    76      9   29     High
# 152         153   20.0    223.0  11.5    68      9   30   Medium
#
# [153 rows x 8 columns]

# %%
df.drop(df.iloc[:,[0]],axis=1,inplace = True)
# inplace=True parameter is commonly used in various methods of data manipulation to modify the object in-place, 
# without creating a new copy of the object. When inplace=True is specified, 
# the method operates directly on the object itself, altering its contents, and returns None.

# %%
df
# Out:
#      Ozone  Solar.R  Wind  Temp  Month  Day Humidity
# 0     41.0    190.0   7.4    67      5    1     High
# 1     36.0    118.0   8.0    72      5    2     High
# 2     12.0    149.0  12.6    74      5    3      NaN
# 3     18.0    313.0  11.5    62      5    4   Medium
# 4      NaN      NaN  14.3    56      5    5      Low
# ..     ...      ...   ...   ...    ...  ...      ...
# 148   30.0    193.0   6.9    70      9   26      Low
# 149    NaN    145.0  13.2    77      9   27      Low
# 150   14.0    191.0  14.3    75      9   28     High
# 151   18.0    131.0   8.0    76      9   29     High
# 152   20.0    223.0  11.5    68      9   30   Medium
#
# [153 rows x 7 columns]

# %%
df.isnull().sum()
# Out:
# Ozone       37
# Solar.R      7
# Wind         0
# Temp         0
# Month        0
# Day          0
# Humidity     9
# dtype: int64

# %%
df['Ozone'].fillna(df['Ozone'].mean(),inplace=True)
df['Solar.R'].fillna(df['Solar.R'].mean(),inplace=True)
df['Humidity'].fillna('Medium',inplace=True)

# %%
df.isnull().sum()
# Out:
# Ozone       0
# Solar.R     0
# Wind        0
# Temp        0
# Month       0
# Day         0
# Humidity    0
# dtype: int64

# %%
'''
inplace=True parameter is commonly used in various methods of data manipulation to modify the object in-place,
without creating a new copy of the object. When inplace=True is specified, the method operates directly on the object itself, 
altering its contents, and returns None.
'''

# %%
df
# Out:
#         Ozone     Solar.R  Wind  Temp  Month  Day Humidity
# 0    41.00000  190.000000   7.4    67      5    1     High
# 1    36.00000  118.000000   8.0    72      5    2     High
# 2    12.00000  149.000000  12.6    74      5    3   Medium
# 3    18.00000  313.000000  11.5    62      5    4   Medium
# 4    42.12931  185.931507  14.3    56      5    5      Low
# ..        ...         ...   ...   ...    ...  ...      ...
# 148  30.00000  193.000000   6.9    70      9   26      Low
# 149  42.12931  145.000000  13.2    77      9   27      Low
# 150  14.00000  191.000000  14.3    75      9   28     High
# 151  18.00000  131.000000   8.0    76      9   29     High
# 152  20.00000  223.000000  11.5    68      9   30   Medium
#
# [153 rows x 7 columns]

# %% [markdown]
# ## Perform label Encoding

# %%
from sklearn.preprocessing import LabelEncoder
le= LabelEncoder()

# %%
df['Humidity']=le.fit_transform(df['Humidity'])

# %%
df
# Out:
#         Ozone     Solar.R  Wind  Temp  Month  Day  Humidity
# 0    41.00000  190.000000   7.4    67      5    1         0
# 1    36.00000  118.000000   8.0    72      5    2         0
# 2    12.00000  149.000000  12.6    74      5    3         2
# 3    18.00000  313.000000  11.5    62      5    4         2
# 4    42.12931  185.931507  14.3    56      5    5         1
# ..        ...         ...   ...   ...    ...  ...       ...
# 148  30.00000  193.000000   6.9    70      9   26         1
# 149  42.12931  145.000000  13.2    77      9   27         1
# 150  14.00000  191.000000  14.3    75      9   28         0
# 151  18.00000  131.000000   8.0    76      9   29         0
# 152  20.00000  223.000000  11.5    68      9   30         2
#
# [153 rows x 7 columns]

# %%
x=df[['Ozone']]
y=df[['Temp']]

# %% [markdown]
# ## Perform modeling using Linear regression

# %%
from sklearn.model_selection import train_test_split

# %%
xtrain,xtest,ytrain,ytest = train_test_split(x,y,test_size=0.2)

# %%
from sklearn import linear_model

# %%
regr= linear_model.LinearRegression()

# %%
model=regr.fit(xtrain,ytrain)

# %%
predict= model.predict(xtest)

# %%
predict
# Out:
# array([[82.22302175],
#        [75.23953639],
#        [76.67731279],
#        [74.21255325],
#        [77.93625247],
#        [73.39096674],
#        [71.95319034],
#        [71.54239708],
#        [72.98017348],
#        [77.29350267],
#        [70.51541394],
#        [77.93625247],
#        [75.03413976],
#        [77.93625247],
#        [92.90364641],
#        [93.5198363 ],
#        [74.00715662],
#        [82.42841838],
#        [77.93625247],
#        [77.93625247],
#        [77.93625247],
#        [75.44493302],
#        [74.00715662],
#        [71.74779371],
#        [70.72081057],
#        [77.93625247],
#        [73.59636337],
#        [74.00715662],
#        [77.93625247],
#        [74.00715662],
#        [85.30397117]])

# %%
from sklearn.metrics import mean_squared_error

# %%
mse=mean_squared_error(ytest,predict)
mse
# Out:
# 73.72388735912786

# %%
rmse=np.sqrt(mse)
rmse
# Out:
# 8.586261547328258

# %%
plt.scatter(xtrain,ytrain,color="red")
plt.plot(xtrain,model.predict(xtrain),color="green")
plt.xlabel('ozone')
plt.ylabel('Temp')
plt.title('Ozone vs Temp ')
# Out:
# Text(0.5, 1.0, 'Ozone vs Temp ')
